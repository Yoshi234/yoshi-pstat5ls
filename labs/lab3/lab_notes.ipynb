# %% [markdown]
# # Gettysburg Address Sampling Activity – Section Guide
#
#
# ## 🎯 Objective
#
# Explore sampling methods using the Gettysburg Address to estimate average word length. Compare self-selected vs. simple random samples and discuss bias and representativeness.
#
# ## ⏱️ Section Breakdown (50 minutes)
#
# - 0–5 min: Introduction & Framing
# Define the population: all 268 words in the Gettysburg Address
# - Define the variable: word length
# - Pose the central question:
# - 5–15 min: Part I – Self-Selected Sampling
# Students choose 10 words they believe are representative
#
# Fill out Table 1.1 with word and length
#
# Create Dotplot 1.1
#
# Discuss shape, center, and variability
#
# ## 15–20 min: Mean Calculation & Class Dotplot
# Compute sample mean (round to 1 decimal place)
#
# Compare with peers
#
# Submit to TA for Dotplot 1.2
#
# ## 20–35 min: Part II – Simple Random Sampling
#
# Use random.org to generate 10 integers (1–268)
#
# Match to word list and fill Table 2.1
#
# Create Dotplot 2.1
#
# Compute sample mean and compare
#
# Submit to TA for Dotplot 2.2
#
# 35–45 min: Compare Sampling Methods
# Compare Dotplot 1.2 vs. Dotplot 2.2
#
# Discuss bias, variability, and representativeness
#
# Emphasize how self-selection may overrepresent longer words
#
# ## 45–50 min: Wrap-Up & Reflection
#
# Show population histogram
#
# Discuss true mean (≈ 4.295)
#
# Reflect on which method better estimates population mean
#
# ⚠️ Trouble Spots to Emphasize
# Random.org usage: demo how to generate distinct integers
#
# Matching integers to word list: offer pre-generated samples if needed
#
# Dotplot construction: provide visual template
#
# Mean calculation: emphasize rounding and checking totals
#
# Bias discussion: use concrete examples to show overrepresentation
#
# 🧑‍🏫 TA Notes
# Bring printed word list (pages 7–8 of the activity)
#
# Prepare blank dotplot templates
#
# Optionally pre-generate random samples for time efficiency
#
# Encourage students to compare and discuss results in pairs

# %% [markdown]
# Email the TA for the 5pm tuesday thursday section about Hudson's attendance
